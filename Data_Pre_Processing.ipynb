# %%
import cv2 # pip install opencv-python,
           # pip install opencv-contrib-python (Full Package)
import os
import matplotlib.pyplot as plt # pip install matplotlib
import numpy as np # pip install numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img_array = cv2.imread("/content/drive/MyDrive/Dataset_update/Train_directory/Closed_Eyes/s0001_00001_0_0_0_0_0_01.png", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_array, cmap="gray")

# %%
img_array.shape
# Out:
# (86, 86)

# %%
backtorgb = cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)

# %%
img_size = 224

new_array = cv2.resize(backtorgb, (img_size,img_size))
new_array=new_array/255.0
plt.imshow(new_array, cmap="gray")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fbb652c56ba2> in <cell line: 1>()
# ----> 1 X = X/255.0;
#
# NameError: name 'X' is not defined
